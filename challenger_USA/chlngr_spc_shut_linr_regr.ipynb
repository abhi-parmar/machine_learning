# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split as tts
# %matplotlib notebook

# %%
data=pd.read_csv("/home/krulvain/codes/datasets/data_crash.csv",delimiter=",",header=None,names=["o_rngss","thm_dst","lnc_tmp","lk_chk_prsr","tmp_ord"])

# %%
data.head()
# Out:
#    o_rngss  thm_dst  lnc_tmp  lk_chk_prsr  tmp_ord
# 0        6        0       66           50        1
# 1        6        1       70           50        2
# 2        6        0       69           50        3
# 3        6        0       68           50        4
# 4        6        0       67           50        5

# %%
data.describe()
# Out:
#        o_rngss    thm_dst    lnc_tmp  lk_chk_prsr   tmp_ord
# count     23.0  23.000000  23.000000    23.000000  23.00000
# mean       6.0   0.304348  69.565217   152.173913  12.00000
# std        0.0   0.558796   7.057080    68.221332   6.78233
# min        6.0   0.000000  53.000000    50.000000   1.00000
# 25%        6.0   0.000000  67.000000    75.000000   6.50000
# 50%        6.0   0.000000  70.000000   200.000000  12.00000
# 75%        6.0   0.500000  75.000000   200.000000  17.50000
# max        6.0   2.000000  81.000000   200.000000  23.00000

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(),annot=True,cmap="BuPu")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
data.drop(["o_rngss","tmp_ord"],inplace=True,axis=1)

# %%
data.head()
# Out:
#    thm_dst  lnc_tmp  lk_chk_prsr
# 0        0       66           50
# 1        1       70           50
# 2        0       69           50
# 3        0       68           50
# 4        0       67           50

# %%
target=data.iloc[:,:1]
features=data.iloc[:,1:]

# %%
trn_inp,tes_inp,trn_out,tes_out=tts(features,target,random_state=0)

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(),annot=True,cmap="BuPu")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
linreg=LinearRegression()

# %%
linreg.fit(trn_inp,trn_out)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pre_inp=np.array([[31,152]])
pre_out=linreg.predict(pre_inp)

# %%
print(" predicted number of O-rings experiencing thermal distress for temperatures immediately below freezing={} therefore , temperature at the time of launch and leak pressure values were responsible for the crash".format(pre_out))
# Out:
#  predicted number of O-rings experiencing thermal distress for temperatures immediately below freezing=[[2.60996627]] therefore , temperature at the time of launch and leak pressure values were responsible for the crash
